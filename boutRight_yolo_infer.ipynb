# %% [markdown]
# # boutRight Code Description
#
# The boutRight project processes bird song recordings to detect and classify bouts using a YOLOv5 model. The code is divided into two main parts:
#
# ## Part 1: Setup and Function Definitions
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `glob`, `shutil`, `torch`, `PIL`, `numpy`, `scipy`, `tqdm`, `io`, `IPython.display`, `concurrent.futures`, `uuid`, `pandas`, and `math`.
#
# 2. **Load YOLOv5 Model**: The YOLOv5 model is loaded with custom weights for detecting bouts in spectrogram images.
#
# 3. **Define Functions**:
#     - `filtered_spectrogram`: Filters and generates a spectrogram from a given audio file. It applies a Butterworth filter, normalizes the signal, and calculates the spectrogram.
#     - `check_for_bouts`: Generates a spectrogram image, uses the YOLOv5 model to detect bouts, and returns the detection results.
#     - `process_wav_file`: Processes each WAV file, moves it to the appropriate directory (`Songs` or `Noise_Calls`), and appends the detection results to CSV files.
#     - `append_to_csv`: Appends detection results to a CSV file, ensuring consistent data formatting.
#     - `get_all_wav_files`: Retrieves all WAV files in a directory, including subdirectories.
#     - `is_already_scanned`: Checks if a file has already been scanned by looking it up in a list of scanned files.
#
# ## Part 2: Processing Bird Song Recordings
#
# 1. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 2. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories and creates them if they don't exist.
#     - It loads the list of already scanned files from `wav_scanned.csv` if available.
#
# 3. **Process WAV Files**:
#     - The script retrieves all WAV files in the hatch day folder, including subdirectories.
#     - It uses a thread pool to process each WAV file concurrently.
#     - For each file, it generates a spectrogram, detects bouts using the YOLOv5 model, and categorizes the files into `Songs` or `Noise_Calls`.
#     - Detection results are appended to `results_bouts.csv` and `results_calls.csv`.
#
# 4. **Handle Duplicates**:
#     - If a file has already been scanned and is detected as a duplicate, a warning is displayed, and the file is deleted.
#
# 5. **Save Scanned Files**:
#     - The list of scanned files is saved to `wav_scanned.csv` to keep track of processed files and avoid reprocessing.
#
# ## Summary
#
# This script is essential for preprocessing and analyzing bird song recordings, enabling the detection and classification of bouts. It ensures efficient processing, categorization, and management of bird song data, facilitating further analysis and research.

# %%
import os
from glob import glob
import shutil
import torch
from PIL import Image
import numpy as np
from scipy.io import wavfile
from scipy import signal
from tqdm import tqdm
import io
from IPython.display import clear_output
import concurrent.futures
import uuid
import pandas as pd
import math
import zipfile
import warnings
import threading
import hashlib

# Initialize a lock object
lock = threading.Lock()

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'custom', path=os.path.join(os.getcwd(),r'yolov5\runs\train\exp13\weights\best.pt'))
#folder to temporarily save images for YOLO detection
#this is needed to run parallel computing without problems
temp_path = r'C:\Temp'

# Function to filter and generate spectrogram
def filtered_spectrogram(filepath):
    # Length of FFT
    lend = 34
    # Overlap of FFT
    overlap = 33
    # Time length for exponential window of FFT
    ts = 3
    # Low cut frequency in Hz
    lc = 500
    # High cut frequency in Hz
    hc = 20000
    # Color of image settings
    # Contribution of each channel to color
    RGBch = [0.8, 1.5, 1.5]

    # Import the audio data
    fs, data = wavfile.read(filepath)
    # Round length of data and overlap
    lend = round((lend / 1E3) * fs)
    overlap = round((overlap / 1E3) * fs)
    # Next power of two definition
    def nextpow2(x):
        return 1 if x == 0 else 2**math.ceil(math.log2(x))
    # Calculate next power of two
    nfft = nextpow2(lend)

    # Butterworth filter
    def butter_bp(data, lc, hc, fs, order=3):
        nyq = 0.5 * fs
        low = lc / nyq
        high = hc / nyq
        b, a = signal.butter(order, [low, high], btype='band')
        data_filtered = signal.lfilter(b, a, data)
        return data_filtered

    data = butter_bp(data, lc, hc, fs, order=5)
    # Normalize signal
    data = data / max(abs(data))
    # Make windows for spectrogram
    t = np.linspace(-lend / 2 + 1, lend / 2, num=lend)
    sigma = (ts / 1E3) * fs
    w = np.exp(-(t / sigma)**2)
    dw = np.exp(-(t / (2 * sigma))**2)
    # Calculate spectrograms
    [f, t, sx] = signal.spectrogram(data, fs=fs, window=w, noverlap=overlap, nfft=nfft)
    [_, _, sxx] = signal.spectrogram(data, fs=fs, window=dw, noverlap=overlap, nfft=nfft)
    # Average of both spectrograms
    image_array = np.log2(abs(sx) + abs(sxx)) / 2
    # Obtain thresholds for background
    minmax = [np.percentile(image_array, 80), np.percentile(image_array, 99)]
    # Subtract background
    image_array = np.minimum(image_array, minmax[1])
    image_array = np.maximum(image_array, minmax[0])
    # Normalize
    image_array = (image_array - np.min(image_array)) / (np.max(image_array) - np.min(image_array))
    # Flip spectrogram
    image_array = np.flip(image_array, 0)
    # Convert to color
    sz = (image_array.shape[0] - 1, image_array.shape[1] - 1, 3)
    image_color = np.zeros(sz)
    tmp = image_array
    image_color[:, :, 0] = RGBch[0] * tmp[0:-1, 0:-1]
    tmp = np.diff(image_array, 1, axis=0)
    image_color[:, :, 1] = RGBch[1] * tmp[:, 0:-1]
    tmp = np.diff(image_array, 1, axis=1)
    image_color[:, :, 2] = RGBch[2] * tmp[0:-1, :]
    
    return image_color, fs, len(data)

# Function to generate spectrogram and check for bouts using YOLOv5
def check_for_bouts(wav_file, temp_path):
    temp_img_path = None
    try:
        # Ensure the temp_path directory exists
        os.makedirs(temp_path, exist_ok=True)
        
        # Generate the spectrogram and convert it to an image
        spectrogram, fs, data_length = filtered_spectrogram(wav_file)
        spectrogram_image = (spectrogram * 255).astype(np.uint8)
        pil_image = Image.fromarray(spectrogram_image)
        
        # Generate a unique filename for the temporary spectrogram image in the temp_path directory
        temp_img_filename = f'temp_spectrogram_{uuid.uuid4().hex}.png'
        temp_img_path = os.path.join(temp_path, temp_img_filename)
        pil_image.save(temp_img_path)
        
        # Verify the saved image
        with Image.open(temp_img_path) as img:
            img.verify()
        
        # Use YOLOv5 to detect bouts in the spectrogram image
        results = model(temp_img_path)
        
        # Filter detections to only include bouts (class 0)
        bouts = [bbox for bbox in results.xyxy[0] if bbox[5] == 0]
        
        # Check if any bouts are detected
        return len(bouts) > 0, results.xyxy[0], spectrogram.shape[1], data_length, fs
    except ValueError as e:
        if "File format" in str(e):
            print(f"Error in check_for_bouts for {wav_file}: {e}")
        else:
            raise e  # Re-raise other types of ValueErrors
        return False, [], 0, 0, 0
    except Exception as e:
        print(f"Error in check_for_bouts for {wav_file}: {e}")
        return False, [], 0, 0, 0
    finally:
        # Remove the temporary image file
        if temp_img_path and os.path.exists(temp_img_path):
            os.remove(temp_img_path)


# Function to process WAV file
def process_wav_file(wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        # Move the file based on detection results
        if has_bouts:
            shutil.move(wav_file, os.path.join(songs_dir, os.path.basename(wav_file)))
            with lock:
                processed_files.add(os.path.basename(wav_file))  # Thread-safe addition
            print(f"Moved {wav_file} to Songs")
        else:
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls")

        # Update scanned files and save to CSV immediately
        with lock:
            scanned_files.append(os.path.basename(wav_file))
            pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)

        return {
            'filepath': wav_file,
            'filename': os.path.basename(wav_file),
            'bboxes': bboxes,
            'spectrogram_length': spectrogram_length,
            'data_length': data_length,
            'fs': fs
        }
    except Exception as e:
        print(f"Error processing {wav_file}: {e}")
        return None

# Function to re-process WAV file that was missed in the original scan
def reprocess_wav_file(wav_file, noise_calls_dir, bouts_csv_path, calls_csv_path):
    try:
        has_bouts, bboxes, spectrogram_length, data_length, fs = check_for_bouts(wav_file, temp_path)

        results = []
        for bbox in bboxes:
            x1, y1, x2, y2, conf, cls = bbox
            entry = {
                'wav_folder_path': os.path.dirname(wav_file),
                'wav_filename': os.path.basename(wav_file),
                'spectrogram_start_time': x1.item(),
                'spectrogram_end_time': x2.item(),
                'wav_file_start_time': (x1.item() / spectrogram_length) * (data_length / fs),
                'wav_file_end_time': (x2.item() / spectrogram_length) * (data_length / fs),
                'confidence': conf.item(),
                'label_class': cls.item(),
                'bbox_x1': x1.item(),
                'bbox_y1': y1.item(),
                'bbox_x2': x2.item(),
                'bbox_y2': y2.item()
            }
            results.append(entry)

        # Append results to CSV files
        if results:
            bouts_results = [entry for entry in results if entry['label_class'] == 0]
            calls_results = [entry for entry in results if entry['label_class'] == 1]

            with lock:
                if bouts_results:
                    append_to_csv(bouts_results, bouts_csv_path)
                if calls_results:
                    append_to_csv(calls_results, calls_csv_path)

        if has_bouts:
            print(f"Reprocessed and found bouts in {wav_file}")
        else:
            print(f"Reprocessed {wav_file}, no bouts found")
            
            # Add this block to move files without bouts to the Noise_Calls folder
            shutil.move(wav_file, os.path.join(noise_calls_dir, os.path.basename(wav_file)))
            print(f"Moved {wav_file} to Noise_Calls after re-scan")

    except Exception as e:
        print(f"Error reprocessing {wav_file}: {e}")


# Function to append results to CSV
def append_to_csv(results, csv_path):
    # Define the expected columns
    columns = [
        'wav_folder_path', 'wav_filename', 'spectrogram_start_time', 'spectrogram_end_time',
        'wav_file_start_time', 'wav_file_end_time', 'confidence', 'label_class',
        'bbox_x1', 'bbox_y1', 'bbox_x2', 'bbox_y2'
    ]
    
    # Convert results to DataFrame
    new_df = pd.DataFrame(results, columns=columns)
    
    # Append to the CSV file
    if os.path.exists(csv_path):
        new_df.to_csv(csv_path, mode='a', header=False, index=False)
    else:
        new_df.to_csv(csv_path, mode='w', header=True, index=False)

# Function to hash individual files to avoid duplicates
def hash_file(filepath):
    """Returns the MD5 hash of the file content."""
    hasher = hashlib.md5()
    with open(filepath, 'rb') as file:
        buf = file.read()
        hasher.update(buf)
    return hasher.hexdigest()

# Function to gather filename of wav files in folders and zip files
def get_all_wav_files(hatch_path, bird_path):
    wav_files = {}  # Use a dictionary to avoid duplicates by file content hash
    songs_dir = os.path.join(hatch_path, 'Songs')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

    # Extract ZIP files recursively
    zip_files = glob(os.path.join(hatch_path, '**', '*.zip'), recursive=True)
    for zip_file in zip_files:
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(hatch_path)
        
        # Move the ZIP file to the birdname folder (at the same level as the mic folder)
        shutil.move(zip_file, os.path.join(bird_path, os.path.basename(zip_file)))

    # Function to add files based on their content hash
    def add_wav_files(dir_path):
        for wav_file in glob(os.path.join(dir_path, '**', '*.wav'), recursive=True):
            file_hash = hash_file(wav_file)
            if file_hash not in wav_files:
                wav_files[file_hash] = wav_file
    
    # Add WAV files from the main directory, Songs, and Noise_Calls
    add_wav_files(hatch_path)
    if os.path.exists(songs_dir):
        add_wav_files(songs_dir)
    if os.path.exists(noise_calls_dir):
        add_wav_files(noise_calls_dir)
    
    return list(wav_files.values())  # Return only the unique file paths

# Function to check if a file has already been scanned
def is_already_scanned(wav_file, scanned_files):
    return os.path.basename(wav_file) in scanned_files

# Function to check if a song file is in the bouts CSV
def is_in_bouts_csv(wav_file, bouts_csv_path):
    if os.path.exists(bouts_csv_path):
        try:
            bouts_df = pd.read_csv(bouts_csv_path)
            return os.path.basename(wav_file) in bouts_df['wav_filename'].values
        except pd.errors.EmptyDataError:
            return False
    return False
# Out:
# Using cache found in C:\Users\Gonzalez Lab/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-9-4 Python-3.12.5 torch-2.4.0 CPU
#
# Fusing layers...
# Model summary: 166 layers, 7056607 parameters, 0 gradients
# Adding AutoShape...

# %%
# Base directory and suppression of warnings remain unchanged
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'
warnings.filterwarnings("ignore", category=FutureWarning, message=".*torch.cuda.amp.autocast.*")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')

    if not os.path.exists(mic_path):
        continue

    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        bird_name = bird_dir
        hatch_day = hatch_folder

        if not os.path.isdir(hatch_path):
            continue

        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')

        # Create Songs and Noise_Calls directories if they don't exist
        os.makedirs(songs_dir, exist_ok=True)
        os.makedirs(noise_calls_dir, exist_ok=True)

        bouts_csv_path = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_day}.csv')
        calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
        scanned_csv_path = os.path.join(hatch_path, f'wav_scanned_{bird_name}_{hatch_day}.csv')

        scanned_files = []
        if os.path.exists(scanned_csv_path):
            try:
                scanned_df = pd.read_csv(scanned_csv_path, on_bad_lines='skip')
                scanned_files = scanned_df['filename'].tolist()
            except pd.errors.EmptyDataError:
                scanned_files = []

        wav_files = get_all_wav_files(hatch_path, bird_path)

        # Filter out already scanned files
        unscanned_wav_files = [wav_file for wav_file in wav_files if not is_already_scanned(wav_file, scanned_files)]

        processed_files = set()  # Thread-safe modification

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = {executor.submit(process_wav_file, wav_file, songs_dir, noise_calls_dir, bouts_csv_path, calls_csv_path, scanned_files, scanned_csv_path, processed_files): wav_file for wav_file in unscanned_wav_files}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(futures), total=len(unscanned_wav_files), desc="Processing WAV files")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 files
                wav_file = futures[future]
                try:
                    result = future.result()
                except Exception as exc:
                    print(f'{wav_file} generated an exception: {exc}')

        # Final check: Ensure all files in Songs appear in both wav_scanned.csv and results_bouts.csv
        song_files_to_rescan = []
        for song_file in glob(os.path.join(songs_dir, '*.wav')):
            if not is_already_scanned(song_file, scanned_files):
                print(f"Appending {song_file} to scanned files")
                with lock:
                    scanned_files.append(os.path.basename(song_file))
                    pd.DataFrame({'filename': scanned_files}).to_csv(scanned_csv_path, index=False)
            if not is_in_bouts_csv(song_file, bouts_csv_path):
                print(f"File {song_file} missing from results_bouts.csv, adding to re-scan list")
                song_files_to_rescan.append(song_file)

        # Parallel processing for the re-scan of song files
        with concurrent.futures.ThreadPoolExecutor() as reprocess_executor:
            reprocess_futures = {reprocess_executor.submit(reprocess_wav_file, song_file, noise_calls_dir, bouts_csv_path, calls_csv_path): song_file for song_file in song_files_to_rescan}
            for i, future in enumerate(tqdm(concurrent.futures.as_completed(reprocess_futures), total=len(song_files_to_rescan), desc="Re-scanning Songs")):
                if i % 10 == 0:
                    clear_output(wait=True)  # Clear the output every 10 iterations
                song_file = reprocess_futures[future]
                try:
                    future.result()
                except Exception as exc:
                    print(f'{song_file} generated an exception during re-scan: {exc}')
# Out:
# Re-scanning Songs:  64%|██████▎   | 202/318 [03:52<02:05,  1.08s/it]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54600900_4_10_15_10_0.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54600900_4_10_15_10_0.wav to Noise_Calls after re-scan
# Re-scanning Songs:  64%|██████▍   | 203/318 [03:52<01:39,  1.16it/s]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54110764_4_10_15_1_50.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54110764_4_10_15_1_50.wav to Noise_Calls after re-scan
# Re-scanning Songs:  64%|██████▍   | 204/318 [03:52<01:27,  1.30it/s]
# Error in check_for_bouts for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54193451_4_10_15_3_13.wav: Sizes of tensors must match except in dimension 4. Expected size 3 but got size 1 for tensor number 2 in the list.
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54193451_4_10_15_3_13.wav, no bouts found
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.58124017_4_10_16_8_44.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54193451_4_10_15_3_13.wav to Noise_Calls after re-scan
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.58124017_4_10_16_8_44.wav to Noise_Calls after re-scan
# Re-scanning Songs:  65%|██████▍   | 206/318 [03:53<01:07,  1.67it/s]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.57928953_4_10_16_5_28.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.57928953_4_10_16_5_28.wav to Noise_Calls after re-scan
# Re-scanning Songs:  65%|██████▌   | 207/318 [03:54<01:15,  1.47it/s]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54716557_4_10_15_11_56.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54716557_4_10_15_11_56.wav to Noise_Calls after re-scan
# Re-scanning Songs:  65%|██████▌   | 208/318 [03:55<01:15,  1.46it/s]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54249559_4_10_15_4_9.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.54249559_4_10_15_4_9.wav to Noise_Calls after re-scan
# Re-scanning Songs:  66%|██████▌   | 209/318 [03:55<01:01,  1.77it/s]
# Reprocessed G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.59396340_4_10_16_29_56.wav, no bouts found
# Moved G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\Songs\B028_45392.59396340_4_10_16_29_56.wav to Noise_Calls after re-scan

# %%
base_dir = r'H:\birdsongs'
bird_dir = os.listdir(base_dir)
bird_path = os.path.join(base_dir, bird_dir[0])
mic_path = os.path.join(bird_path,'mic')
hatch_folder= os.listdir(mic_path)
hatch_path = os.path.join(mic_path, hatch_folder[2])
hatch_path
songs_dir = os.path.join(hatch_path, 'Songs')
noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
bouts_csv_path = os.path.join(hatch_path, 'results_bouts.csv')
calls_csv_path = os.path.join(hatch_path, 'results_calls.csv')
scanned_files = []

# Load scanned files if the CSV exists
scanned_csv_path = os.path.join(hatch_path, 'wav_scanned.csv')
scanned_df = pd.read_csv(scanned_csv_path, on_bad_lines='skip')

scanned_files = scanned_df['filename'].tolist()

hatch_path
wav_files = get_all_wav_files(hatch_path, bird_path)
os.path.basename(wav_file[0]) in scanned_files
unscanned_wav_files = [wav_file for wav_file in wav_file if not is_already_scanned(wav_file, scanned_files)]
unscanned_wav_files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 base_dir = r'H:\birdsongs'
# ----> 2 bird_dir = os.listdir(base_dir)
#       3 bird_path = os.path.join(base_dir, bird_dir[0])
#       4 mic_path = os.path.join(bird_path,'mic')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'H:\\birdsongs'

# %% [markdown]
# # Remove noise and call wav files which have the least amount of calls
#
# This script processes bird song recordings to manage and retain the top 100 WAV files with the most calls in each hatch day folder. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, and `glob`.
#
# 2. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 3. **Define Function**:
#     - `process_hatch_day_folder`: This function processes each hatch day folder by:
#         - Checking if the `results_calls.csv` file exists.
#         - Loading the CSV file and counting the number of calls in each WAV file.
#         - Sorting the files by call count and retaining the top 100.
#         - Deleting the remaining files in the `Noise_Calls` folder.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it calls the `process_hatch_day_folder` function to manage the WAV files based on the number of calls.
#
# This script helps in organizing and retaining the most relevant bird song recordings for further analysis.

# %%
import os
import csv
import pandas as pd
from glob import glob

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'

# Function to process each hatch day folder
def process_hatch_day_folder(hatch_path, bird_name, hatch_day):
    calls_csv_path = os.path.join(hatch_path, f'results_calls_{bird_name}_{hatch_day}.csv')
    noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
    
    # Check if the calls CSV file exists
    if not os.path.exists(calls_csv_path):
        print(f"No CSV file found for {hatch_path}. Skipping...")
        return
    
    try:
        # Load the calls CSV file
        calls_df = pd.read_csv(calls_csv_path, on_bad_lines='skip')
        
        if calls_df.empty:
            print(f"No data in {calls_csv_path}. Skipping...")
            return
        
        # Group by filename and count the number of calls
        call_counts = calls_df.groupby('wav_filename').size().reset_index(name='call_count')
        
        # Sort by call count in descending order and keep the top 100
        top_calls = call_counts.sort_values(by='call_count', ascending=False).head(100)
        
        # Get the list of top 100 filenames
        top_filenames = top_calls['wav_filename'].tolist()
        
        # Get all WAV files in the Noise_Calls folder
        all_wav_files = glob(os.path.join(noise_calls_dir, '*.wav'))
        
        # Delete files not in the top 100
        for wav_file in all_wav_files:
            if os.path.basename(wav_file) not in top_filenames:
                os.remove(wav_file)
                print(f"Deleted {wav_file}")
    except pd.errors.EmptyDataError:
        print(f"EmptyDataError: No columns to parse from file {calls_csv_path}")

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        bird_name = bird_dir
        hatch_day = hatch_folder
        
        process_hatch_day_folder(hatch_path, bird_name, hatch_day)


def align_csv_columns(file_path, expected_columns=12):
    aligned_rows = []
    
    try:
        with open(file_path, 'r') as infile:
            reader = csv.reader(infile)
            for row in reader:
                # Count non-empty cells
                non_empty_cells = [cell for cell in row if cell]
                
                if len(non_empty_cells) == expected_columns:
                    # Shift the row to start at column 1 and ensure it has exactly 12 columns
                    aligned_row = non_empty_cells[:expected_columns]
                else:
                    aligned_row = row
                
                # Ensure the row has exactly 12 columns
                aligned_row = aligned_row[:expected_columns]
                
                aligned_rows.append(aligned_row)
        
        with open(file_path, 'w', newline='') as outfile:
            writer = csv.writer(outfile)
            writer.writerows(aligned_rows)
        print(f"CSV columns aligned successfully for {file_path}.")
    
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")

def process_hatch_folders(base_path, expected_columns=12):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.startswith('results_bout') or file.startswith('results_call'):
                file_path = os.path.join(root, file)
                align_csv_columns(file_path, expected_columns)

# Fix excel files
process_hatch_folders(base_dir)
# Out:
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24389694_5_9_6_46_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24429282_5_9_6_47_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24447321_5_9_6_47_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24478364_5_9_6_47_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24510013_5_9_6_48_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24546328_5_9_6_49_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24615920_5_9_6_50_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24666698_5_9_6_51_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24834919_5_9_6_53_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24840992_5_9_6_54_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.24912943_5_9_6_55_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25524350_5_9_7_5_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25542837_5_9_7_5_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25630122_5_9_7_7_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25923528_5_9_7_12_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25941888_5_9_7_12_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.25984429_5_9_7_13_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.26157637_5_9_7_15_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.26511059_5_9_7_21_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.26553980_5_9_7_22_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.26804140_5_9_7_26_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.27083149_5_9_7_31_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.27246200_5_9_7_34_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.27655561_5_9_7_40_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.27898622_5_9_7_44_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.27985289_5_9_7_46_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.28481142_5_9_7_54_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.31452175_5_9_8_44_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.31464179_5_9_8_44_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.31779673_5_9_8_49_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.31804927_5_9_8_50_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.32194350_5_9_8_56_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.32226950_5_9_8_57_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.32540097_5_9_9_2_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.32827857_5_9_9_7_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.33757803_5_9_9_22_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.33768863_5_9_9_22_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.34301445_5_9_9_31_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.34324978_5_9_9_32_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.36216935_5_9_10_3_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.36285432_5_9_10_4_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37132856_5_9_10_18_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37152934_5_9_10_19_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37198817_5_9_10_19_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37245398_5_9_10_20_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37279125_5_9_10_21_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37311715_5_9_10_21_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37454904_5_9_10_24_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37654576_5_9_10_27_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37824295_5_9_10_30_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37839466_5_9_10_30_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37859919_5_9_10_30_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.37943317_5_9_10_32_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38008257_5_9_10_33_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38062716_5_9_10_34_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38071146_5_9_10_34_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38209852_5_9_10_36_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38245954_5_9_10_37_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38258687_5_9_10_37_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38297247_5_9_10_38_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38319383_5_9_10_38_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.38461540_5_9_10_41_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44144717_5_9_12_15_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44455607_5_9_12_20_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44488353_5_9_12_21_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44551117_5_9_12_22_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44587512_5_9_12_23_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44707810_5_9_12_25_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44921962_5_9_12_28_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.44976753_5_9_12_29_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45040647_5_9_12_30_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45063966_5_9_12_31_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45129274_5_9_12_32_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45164699_5_9_12_32_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45229984_5_9_12_33_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45262445_5_9_12_34_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45299166_5_9_12_34_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45318802_5_9_12_35_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45337111_5_9_12_35_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45433095_5_9_12_37_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45480678_5_9_12_38_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.45623350_5_9_12_40_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46108463_5_9_12_48_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46123229_5_9_12_48_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46169592_5_9_12_49_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46186039_5_9_12_49_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46231139_5_9_12_50_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46290952_5_9_12_51_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46312965_5_9_12_51_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46417993_5_9_12_53_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46599819_5_9_12_56_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46854867_5_9_13_0_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.46908957_5_9_13_1_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.47382880_5_9_13_9_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.47612141_5_9_13_13_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48080991_5_9_13_21_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48439640_5_9_13_27_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48471017_5_9_13_27_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48533967_5_9_13_28_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48597053_5_9_13_29_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48660100_5_9_13_31_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48754812_5_9_13_32_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.48986671_5_9_13_36_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.49089248_5_9_13_38_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.49116653_5_9_13_38_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.49334065_5_9_13_42_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50011805_5_9_13_53_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50037378_5_9_13_53_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50087483_5_9_13_54_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50119157_5_9_13_55_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50144631_5_9_13_55_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50160118_5_9_13_56_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50237478_5_9_13_57_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50302426_5_9_13_58_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50474620_5_9_14_1_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50527028_5_9_14_2_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50587880_5_9_14_3_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50799705_5_9_14_6_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50823416_5_9_14_7_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50917651_5_9_14_8_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50926141_5_9_14_8_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50959680_5_9_14_9_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.50974006_5_9_14_9_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.51051558_5_9_14_10_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.51113821_5_9_14_11_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.51170748_5_9_14_12_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.51381742_5_9_14_16_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.51553765_5_9_14_19_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52088094_5_9_14_28_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52139076_5_9_14_28_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52170751_5_9_14_29_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52288202_5_9_14_31_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52330266_5_9_14_32_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52402150_5_9_14_33_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52424412_5_9_14_33_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52433606_5_9_14_33_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52622670_5_9_14_37_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52693169_5_9_14_38_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52793723_5_9_14_39_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52855403_5_9_14_40_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.52924634_5_9_14_42_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53222929_5_9_14_47_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53318983_5_9_14_48_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53332111_5_9_14_48_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53611623_5_9_14_53_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53636432_5_9_14_53_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53664864_5_9_14_54_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53679513_5_9_14_54_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53690411_5_9_14_54_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53718442_5_9_14_55_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53935182_5_9_14_58_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53964974_5_9_14_59_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.53996994_5_9_14_59_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54028714_5_9_15_0_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54052617_5_9_15_0_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54084429_5_9_15_1_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54109832_5_9_15_1_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54134836_5_9_15_2_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54166412_5_9_15_2_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54207545_5_9_15_3_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54277324_5_9_15_4_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54302417_5_9_15_5_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54334563_5_9_15_5_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54348465_5_9_15_5_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54380014_5_9_15_6_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54391170_5_9_15_6_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54402556_5_9_15_6_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54465115_5_9_15_7_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54595116_5_9_15_9_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54615413_5_9_15_10_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54688687_5_9_15_11_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54761886_5_9_15_12_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54789626_5_9_15_13_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54904462_5_9_15_15_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.54927338_5_9_15_15_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55045628_5_9_15_17_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55133427_5_9_15_18_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55141804_5_9_15_19_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55246482_5_9_15_20_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55260928_5_9_15_21_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.55270309_5_9_15_21_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56025163_5_9_15_33_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56045858_5_9_15_34_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56062338_5_9_15_34_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56150826_5_9_15_35_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56259553_5_9_15_37_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56320650_5_9_15_38_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.56509553_5_9_15_41_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57770752_5_9_16_2_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57801500_5_9_16_3_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57838305_5_9_16_3_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57882438_5_9_16_4_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57931179_5_9_16_5_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57941065_5_9_16_5_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57966513_5_9_16_6_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57987684_5_9_16_6_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.57994116_5_9_16_6_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58047387_5_9_16_7_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58132249_5_9_16_8_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58151447_5_9_16_9_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58170266_5_9_16_9_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58187773_5_9_16_9_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58208821_5_9_16_10_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58230454_5_9_16_10_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58240919_5_9_16_10_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58265919_5_9_16_11_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58322207_5_9_16_12_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58435621_5_9_16_13_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58451183_5_9_16_14_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58474980_5_9_16_14_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58497709_5_9_16_14_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58562540_5_9_16_16_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58581528_5_9_16_16_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58603525_5_9_16_16_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58637327_5_9_16_17_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58668897_5_9_16_17_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58747605_5_9_16_19_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58755287_5_9_16_19_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58832316_5_9_16_20_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58868982_5_9_16_21_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58952530_5_9_16_22_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.58999078_5_9_16_23_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59046198_5_9_16_24_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59078247_5_9_16_24_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59208267_5_9_16_26_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59239807_5_9_16_27_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59323279_5_9_16_28_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59360342_5_9_16_29_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59399398_5_9_16_29_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59432877_5_9_16_30_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59447593_5_9_16_30_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59462730_5_9_16_31_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59480103_5_9_16_31_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.59492045_5_9_16_31_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.61567405_5_9_17_6_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.61768962_5_9_17_9_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.61974371_5_9_17_12_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64269894_5_9_17_51_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64390743_5_9_17_53_10.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64413146_5_9_17_53_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64444832_5_9_17_54_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64508069_5_9_17_55_8.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64534233_5_9_17_55_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64552276_5_9_17_55_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64732191_5_9_17_58_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64764250_5_9_17_59_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64801151_5_9_18_0_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64852233_5_9_18_0_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64866434_5_9_18_1_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64877732_5_9_18_1_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64957943_5_9_18_2_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.64968030_5_9_18_2_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67401187_5_9_18_43_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67421841_5_9_18_43_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67473262_5_9_18_44_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67484257_5_9_18_44_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67538826_5_9_18_45_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67556498_5_9_18_45_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67613103_5_9_18_46_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67678234_5_9_18_47_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67696060_5_9_18_48_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67811902_5_9_18_50_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.67871779_5_9_18_51_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68016024_5_9_18_53_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68135989_5_9_18_55_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68192015_5_9_18_56_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68209278_5_9_18_56_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68260920_5_9_18_57_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68275461_5_9_18_57_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68304879_5_9_18_58_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68340041_5_9_18_59_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68387330_5_9_18_59_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68475947_5_9_19_1_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68531929_5_9_19_2_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68551117_5_9_19_2_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68562977_5_9_19_2_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68576264_5_9_19_2_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68640704_5_9_19_4_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68691780_5_9_19_4_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68755234_5_9_19_5_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68781248_5_9_19_6_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.68908602_5_9_19_8_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.69224002_5_9_19_13_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70234545_5_9_19_30_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70243649_5_9_19_30_43.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70296657_5_9_19_31_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70308584_5_9_19_31_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70329338_5_9_19_32_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70402270_5_9_19_33_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.70451495_5_9_19_34_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.71057087_5_9_19_44_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.71886010_5_9_19_58_6.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.73730998_5_9_20_28_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.73913610_5_9_20_31_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.73961766_5_9_20_32_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\Noise_Calls\8UWL2_45421.73993116_5_9_20_33_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23593906_5_10_6_33_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23784599_5_10_6_36_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23799377_5_10_6_36_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23844336_5_10_6_37_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23926959_5_10_6_38_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.23990643_5_10_6_39_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24029043_5_10_6_40_29.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24083717_5_10_6_41_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24164548_5_10_6_42_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24179915_5_10_6_42_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24218787_5_10_6_43_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24234835_5_10_6_43_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24411360_5_10_6_46_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24560668_5_10_6_49_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24621097_5_10_6_50_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24873410_5_10_6_54_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24904650_5_10_6_55_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24919059_5_10_6_55_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24930490_5_10_6_55_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24962105_5_10_6_56_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.24993738_5_10_6_56_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25005594_5_10_6_56_45.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25100747_5_10_6_58_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25151723_5_10_6_59_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25215514_5_10_7_0_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25247820_5_10_7_0_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25279906_5_10_7_1_19.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25290788_5_10_7_1_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25301868_5_10_7_1_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25322168_5_10_7_2_2.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25563724_5_10_7_6_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.25673893_5_10_7_7_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26742593_5_10_7_25_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26792825_5_10_7_26_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26809515_5_10_7_26_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26842243_5_10_7_27_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26869118_5_10_7_27_49.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26913475_5_10_7_28_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.26939070_5_10_7_28_59.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27020179_5_10_7_30_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27048162_5_10_7_30_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27072376_5_10_7_31_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27088598_5_10_7_31_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27180536_5_10_7_33_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27200317_5_10_7_33_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27237905_5_10_7_33_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27301650_5_10_7_35_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27327610_5_10_7_35_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27917639_5_10_7_45_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.27961486_5_10_7_46_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.29220079_5_10_8_7_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.29235526_5_10_8_7_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.29260632_5_10_8_7_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.29280916_5_10_8_8_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30274464_5_10_8_24_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30410666_5_10_8_26_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30517091_5_10_8_28_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30803922_5_10_8_33_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30836742_5_10_8_33_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30853337_5_10_8_34_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30880959_5_10_8_34_40.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.30969257_5_10_8_36_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31287199_5_10_8_41_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31298083_5_10_8_41_38.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31325678_5_10_8_42_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31346003_5_10_8_42_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31381137_5_10_8_43_1.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31389622_5_10_8_43_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31396609_5_10_8_43_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31883905_5_10_8_51_23.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31953608_5_10_8_52_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31966080_5_10_8_52_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.31983087_5_10_8_53_3.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32097071_5_10_8_54_57.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32116394_5_10_8_55_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32148146_5_10_8_55_48.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32180749_5_10_8_56_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32187899_5_10_8_56_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32194992_5_10_8_56_34.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32231498_5_10_8_57_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32278159_5_10_8_57_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32322515_5_10_8_58_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32371389_5_10_8_59_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32411805_5_10_9_0_11.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32424936_5_10_9_0_24.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32561161_5_10_9_2_41.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32597716_5_10_9_3_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32647249_5_10_9_4_7.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32691139_5_10_9_4_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32752372_5_10_9_5_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32807102_5_10_9_6_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32824044_5_10_9_7_4.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32834791_5_10_9_7_14.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32852678_5_10_9_7_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32862223_5_10_9_7_42.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32876220_5_10_9_7_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32910982_5_10_9_8_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.32953840_5_10_9_9_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33051689_5_10_9_10_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33296844_5_10_9_14_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33420317_5_10_9_17_0.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33437645_5_10_9_17_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33471076_5_10_9_17_51.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33512016_5_10_9_18_32.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33639997_5_10_9_20_39.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33757640_5_10_9_22_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33800666_5_10_9_23_20.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33916122_5_10_9_25_16.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.33986743_5_10_9_26_26.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.34041037_5_10_9_27_21.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.34053806_5_10_9_27_33.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.34067504_5_10_9_27_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35038875_5_10_9_43_58.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35136888_5_10_9_45_36.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35155392_5_10_9_45_55.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35197827_5_10_9_46_37.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35229402_5_10_9_47_9.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35292618_5_10_9_48_12.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35330510_5_10_9_48_50.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35362043_5_10_9_49_22.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35394297_5_10_9_49_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35425894_5_10_9_50_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35454832_5_10_9_50_54.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35487233_5_10_9_51_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35550535_5_10_9_52_30.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35585664_5_10_9_53_5.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35607384_5_10_9_53_27.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.35658323_5_10_9_54_18.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.36013259_5_10_10_0_13.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.36586864_5_10_10_9_46.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.36685819_5_10_10_11_25.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.37157512_5_10_10_19_17.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.37433837_5_10_10_23_53.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.37547398_5_10_10_25_47.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.37556910_5_10_10_25_56.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.37828622_5_10_10_30_28.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38075741_5_10_10_34_35.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38115632_5_10_10_35_15.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38191389_5_10_10_36_31.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38204073_5_10_10_36_44.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38212944_5_10_10_36_52.wav
# Deleted G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\Noise_Calls\8UWL2_45422.38256654_5_10_10_37_36.wav
# ...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\223. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\224. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\225. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\226. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\228. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\229. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\230. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\231. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\232. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\233. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\234. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\235. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\236. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\237. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\238. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\239. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\240. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\R97\mic\241. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\107. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\108. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\109. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\110. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\111. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\112. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\RO3\mic\syntax_analysis. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\350. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\351. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\352. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\353. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\354. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\355. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\356. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\357. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\358. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\359. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\360. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\361. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\362. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\363. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\364. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\365. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\366. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\367. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\368. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\369. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\370. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\371. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\372. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\373. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\374. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\375. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\376. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\377. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\378. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\379. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\380. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\381. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\382. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\383. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\384. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\385. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\386. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\387. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\388. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\389. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\390. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\391. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\392. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\393. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\395. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\396. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\397. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\398. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\399. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\400. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\401. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\402. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\409. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\410. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\411. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\412. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\413. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\414. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\415. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\416. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\417. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\418. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\419. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\420. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\421. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\422. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\423. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\424. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\425. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\426. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\427. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\428. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\429. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\430. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\431. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\432. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\433. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\434. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\435. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\W68Pi45\mic\439. Skipping...
# No CSV file found for G:\Lab Dropbox\BirdSong\BirdData_2024\Y11\mic\25. Skipping...
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\results_bouts_8UWL2_129.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\129\results_calls_8UWL2_129.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\results_bouts_8UWL2_130.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\130\results_calls_8UWL2_130.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\131\results_bouts_8UWL2_131.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\131\results_calls_8UWL2_131.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\132\results_bouts_8UWL2_132.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\132\results_calls_8UWL2_132.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\133\results_bouts_8UWL2_133.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\133\results_calls_8UWL2_133.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\134\results_bouts_8UWL2_134.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\134\results_calls_8UWL2_134.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\135\results_bouts_8UWL2_135.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\135\results_calls_8UWL2_135.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\136\results_bouts_8UWL2_136.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\136\results_calls_8UWL2_136.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\137\results_bouts_8UWL2_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\137\results_calls_8UWL2_137.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\138\results_bouts_8UWL2_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\138\results_calls_8UWL2_138.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\139\results_bouts_8UWL2_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\139\results_calls_8UWL2_139.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\140\results_bouts_8UWL2_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\140\results_calls_8UWL2_140.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\141\results_bouts_8UWL2_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\141\results_calls_8UWL2_141.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\142\results_bouts_8UWL2_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\142\results_calls_8UWL2_142.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\143\results_bouts_8UWL2_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\143\results_calls_8UWL2_143.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\144\results_bouts_8UWL2_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\144\results_calls_8UWL2_144.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\145\results_bouts_8UWL2_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\145\results_calls_8UWL2_145.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\146\results_bouts_8UWL2_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\146\results_calls_8UWL2_146.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\147\results_bouts_8UWL2_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\147\results_calls_8UWL2_147.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\148\results_bouts_8UWL2_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\148\results_calls_8UWL2_148.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\149\results_bouts_8UWL2_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\mic\149\results_calls_8UWL2_149.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\results_bouts_B028_100.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\100\results_calls_B028_100.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\101\results_bouts_B028_101.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\101\results_calls_B028_101.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\102\results_bouts_B028_102.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\102\results_calls_B028_102.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\103\results_bouts_B028_103.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\103\results_calls_B028_103.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\104\results_bouts_B028_104.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\104\results_calls_B028_104.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\105\results_bouts_B028_105.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\105\results_calls_B028_105.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\106\results_bouts_B028_106.csv.
# CSV columns aligned successfully for G:\Lab Dropbox\BirdSong\BirdData_2024\B028\mic\106\results_calls_B028_106.csv.

# %% [markdown]
# # Simple bout analytics
#
# This script processes bird song recordings to generate and save plots for the distribution of bout durations and YOLO confidence scores. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `pandas`, `matplotlib.pyplot`, and `os`.
#
# 2. **Define Functions**:
#     - `plot_bout_durations`: This function calculates and plots the distribution of bout durations from the `results_bouts.csv` file. It saves the plot as an SVG file.
#     - `plot_yolo_confidence`: This function calculates and plots the distribution of YOLO confidence scores from the `results_bouts.csv` and `results_calls.csv` files. It saves the plot as an SVG file.
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` and `results_calls.csv` if available.
#     - It calls the `plot_bout_durations` and `plot_yolo_confidence` functions to generate and save the plots.
#
# 5. **Output**: The script prints a message indicating that the plots have been generated and saved successfully.
#
# This script helps in visualizing the distribution of bout durations and YOLO confidence scores for bird song recordings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'

# Function to plot and save the heatmap of bout duration distributions across hatch days
def plot_bout_duration_heatmap(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout durations for each hatch day
    bout_durations = {}
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
                    bout_durations[hatch_folder] = bouts_df['duration'].tolist()
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_durations:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Create a DataFrame from the dictionary
    max_duration = 6  # Limit the duration to 6 seconds
    num_bins = 20
    duration_bins = pd.cut([0, max_duration], bins=num_bins, retbins=True)[1]  # Get the bin edges
    
    heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
    
    for hatch_folder, durations in bout_durations.items():
        # Filter durations to be within 0 to 6 seconds
        filtered_durations = [d for d in durations if 0 <= d <= max_duration]
        if filtered_durations:
            duration_counts = pd.cut(filtered_durations, bins=duration_bins).value_counts()
            heatmap_data.loc[hatch_folder] = duration_counts.values
    
    # Normalize the data to represent probabilities
    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0).fillna(0)
    
    # Plot the heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(heatmap_data, cmap="YlGnBu", cbar_kws={'label': 'Probability'}, xticklabels=[f'{x:.2f}' for x in duration_bins[:-1]])
    plt.title(f'Bout Duration Distribution Heatmap for {bird_name}')
    plt.xlabel('Duration (seconds)')
    plt.ylabel('Hatch Day')
    
    # Save the heatmap as a vector image
    heatmap_file = os.path.join(bird_path, 'bout_duration_heatmap.svg')
    plt.savefig(heatmap_file)
    plt.close()
    print(f"Heatmap saved for {bird_name} at {heatmap_file}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the heatmap of bout duration distributions across hatch days
    plot_bout_duration_heatmap(bird_path, bird_name)

print("Heatmaps have been generated and saved successfully.")
# Out:
# C:\Users\Gonzalez Lab\AppData\Local\Temp\ipykernel_9176\212368767.py:39: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# Heatmap saved for 8UWL2 at G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\bout_duration_heatmap.svg
# C:\Users\Gonzalez Lab\AppData\Local\Temp\ipykernel_9176\212368767.py:39: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=range(num_bins)).fillna(0)
# Heatmap saved for B028 at G:\Lab Dropbox\BirdSong\BirdData_2024\B028\bout_duration_heatmap.svg
# No valid bout data found for B033
# No valid bout data found for B045
# No valid bout data found for B17Y4
# No valid bout data found for Bk19
# No valid bout data found for Bk52W16
# No valid bout data found for BK6
# No valid bout data found for BK8W98
# No valid bout data found for EVC2303
# No valid bout data found for Gr30
# No valid bout data found for NoBa01
# No valid bout data found for NoBa02
# No valid bout data found for Or04
# No valid bout data found for OR09V022V023
# No valid bout data found for R02
# No valid bout data found for R03
# No valid bout data found for R04
# No valid bout data found for R07
# No valid bout data found for R08
# No valid bout data found for R104
# No valid bout data found for R120
# No valid bout data found for R15
# No valid bout data found for R155
# No valid bout data found for R156
# No valid bout data found for R159
# No valid bout data found for R16
# No valid bout data found for R17
# No valid bout data found for R19
# No valid bout data found for R22
# No valid bout data found for R26
# No valid bout data found for R26a
# No valid bout data found for R29
# No valid bout data found for R29B11
# No valid bout data found for R30
# No valid bout data found for R32
# No valid bout data found for R37
# No valid bout data found for R38
# No valid bout data found for R42
# No valid bout data found for R44
# No valid bout data found for R55
# No valid bout data found for R58
# No valid bout data found for R95
# No valid bout data found for R97
# No valid bout data found for RO3
# No valid bout data found for W68Pi45
# No valid bout data found for Y11
# Heatmaps have been generated and saved successfully.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Base directory
base_dir = r'G:\Lab Dropbox\BirdSong\BirdData_2024'

# Function to plot and save the heatmap of bout duration distributions across hatch days
def plot_bout_duration_heatmap(bird_path, bird_name):
    mic_path = os.path.join(bird_path, 'mic')
    hatch_folders = [f for f in os.listdir(mic_path) if os.path.isdir(os.path.join(mic_path, f))]
    
    # Dictionary to store bout durations for each hatch day
    bout_durations = {}
    
    for hatch_folder in hatch_folders:
        hatch_path = os.path.join(mic_path, hatch_folder)
        bouts_file = os.path.join(hatch_path, f'results_bouts_{bird_name}_{hatch_folder}.csv')
        
        if os.path.exists(bouts_file):
            try:
                bouts_df = pd.read_csv(bouts_file)
                if not bouts_df.empty:
                    bouts_df['duration'] = bouts_df['wav_file_end_time'] - bouts_df['wav_file_start_time']
                    bout_durations[hatch_folder] = bouts_df['duration'].tolist()
            except pd.errors.EmptyDataError:
                print(f"EmptyDataError: No columns to parse from file {bouts_file}")
    
    if not bout_durations:
        print(f"No valid bout data found for {bird_name}")
        return
    
    # Create a DataFrame from the dictionary
    max_duration = max([max(durations) for durations in bout_durations.values()])
    duration_bins = range(0, int(max_duration) + 1)
    
    heatmap_data = pd.DataFrame(index=hatch_folders, columns=duration_bins).fillna(0)
    
    for hatch_folder, durations in bout_durations.items():
        duration_counts = pd.Series(durations).value_counts(bins=duration_bins, sort=False)
        heatmap_data.loc[hatch_folder] = duration_counts
    
    # Normalize the data to represent probabilities
    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0).fillna(0)
    
    # Plot the heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(heatmap_data, cmap="YlGnBu", cbar_kws={'label': 'Probability'})
    plt.title(f'Bout Duration Distribution Heatmap for {bird_name}')
    plt.xlabel('Duration (seconds)')
    plt.ylabel('Hatch Day')
    
    # Save the heatmap as a vector image
    heatmap_file = os.path.join(bird_path, 'bout_duration_heatmap.svg')
    plt.savefig(heatmap_file)
    plt.close()
    print(f"Heatmap saved for {bird_name} at {heatmap_file}")


# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    bird_name = bird_dir
    
    # Plot and save the heatmap of bout duration distributions across hatch days
    plot_bout_duration_heatmap(bird_path, bird_name)

print("Heatmaps have been generated and saved successfully.")
# Out:
# C:\Users\Gonzalez Lab\AppData\Local\Temp\ipykernel_9176\280924931.py:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=duration_bins).fillna(0)
# Heatmap saved for 8UWL2 at G:\Lab Dropbox\BirdSong\BirdData_2024\8UWL2\bout_duration_heatmap.svg
# C:\Users\Gonzalez Lab\AppData\Local\Temp\ipykernel_9176\280924931.py:38: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = pd.DataFrame(index=hatch_folders, columns=duration_bins).fillna(0)
# Heatmap saved for B028 at G:\Lab Dropbox\BirdSong\BirdData_2024\B028\bout_duration_heatmap.svg
# No valid bout data found for B033
# No valid bout data found for B045
# No valid bout data found for B17Y4
# No valid bout data found for Bk19
# No valid bout data found for Bk52W16
# No valid bout data found for BK6
# No valid bout data found for BK8W98
# No valid bout data found for EVC2303
# No valid bout data found for Gr30
# No valid bout data found for NoBa01
# No valid bout data found for NoBa02
# No valid bout data found for Or04
# No valid bout data found for OR09V022V023
# No valid bout data found for R02
# No valid bout data found for R03
# No valid bout data found for R04
# No valid bout data found for R07
# No valid bout data found for R08
# No valid bout data found for R104
# No valid bout data found for R120
# No valid bout data found for R15
# No valid bout data found for R155
# No valid bout data found for R156
# No valid bout data found for R159
# No valid bout data found for R16
# No valid bout data found for R17
# No valid bout data found for R19
# No valid bout data found for R22
# No valid bout data found for R26
# No valid bout data found for R26a
# No valid bout data found for R29
# No valid bout data found for R29B11
# No valid bout data found for R30
# No valid bout data found for R32
# No valid bout data found for R37
# No valid bout data found for R38
# No valid bout data found for R42
# No valid bout data found for R44
# No valid bout data found for R55
# No valid bout data found for R58
# No valid bout data found for R95
# No valid bout data found for R97
# No valid bout data found for RO3
# No valid bout data found for W68Pi45
# No valid bout data found for Y11
# Heatmaps have been generated and saved successfully.

# %% [markdown]
# # bout Entropy analytics
#
# This script processes bird song recordings to calculate and visualize the spectral entropy of detected bouts. The steps are as follows:
#
# 1. **Import Libraries**: The script imports necessary libraries including `os`, `pandas`, `numpy`, `scipy`, and `matplotlib`.
#
# 2. **Define Function**:
#     - `calculate_spectral_entropy`: This function computes the spectral entropy of a given signal using the Short-Time Fourier Transform (STFT).
#
# 3. **Set Base Directory**: The base directory containing bird song recordings is specified.
#
# 4. **Process Each Bird's Mic Folder**:
#     - The script iterates through each bird's mic folder.
#     - For each hatch day folder, it checks for the existence of `Songs` and `Noise_Calls` directories.
#     - It loads the results from `results_bouts.csv` if available.
#
# 5. **Process Each Bout**:
#     - For each bout in the CSV file, the corresponding WAV file is read.
#     - A region of interest (ROI) around the bout is extracted with 1-second padding.
#     - The spectral entropy of the bout signal is calculated and stored.
#
# 6. **Sort and Align Bouts**:
#     - The bouts are sorted based on their total spectral entropy.
#     - All bouts are aligned to a common signal at the start of the bout using cross-correlation.
#
# 7. **Visualize Spectral Entropy**:
#     - A figure is created where each row represents a bout, the x-axis is time, and the color represents the spectral entropy.
#     - The figure is saved as an SVG file and displayed.
#
# This script helps in analyzing and visualizing the complexity of bird songs by calculating and aligning the spectral entropy of detected bouts.

# %%
import os
import pandas as pd
import numpy as np
from scipy.io import wavfile
from scipy.signal import spectrogram
import matplotlib.pyplot as plt

# Function to calculate spectral entropy
def calculate_spectral_entropy(signal, fs, nperseg=256, noverlap=128):
    f, t, Sxx = spectrogram(signal, fs, nperseg=nperseg, noverlap=noverlap)
    Sxx_norm = Sxx / np.sum(Sxx, axis=0)
    spectral_entropy = -np.sum(Sxx_norm * np.log2(Sxx_norm + 1e-10), axis=0)
    return spectral_entropy

# Base directory
base_dir = r'C:\Users\ucsfg\Documents\Code\boutRight_v3\birdsong'

# Process each bird's mic folder
for bird_dir in os.listdir(base_dir):
    bird_path = os.path.join(base_dir, bird_dir)
    mic_path = os.path.join(bird_path, 'mic')
    
    if not os.path.exists(mic_path):
        continue
    
    for hatch_folder in os.listdir(mic_path):
        hatch_path = os.path.join(mic_path, hatch_folder)
        
        if not os.path.isdir(hatch_path):
            continue
        
        songs_dir = os.path.join(hatch_path, 'Songs')
        noise_calls_dir = os.path.join(hatch_path, 'Noise_Calls')
        
        if not os.path.exists(songs_dir) or not os.path.exists(noise_calls_dir):
            continue
        
        # Load results from CSV
        results_csv = os.path.join(hatch_path, 'results_bouts.csv')
        if not os.path.exists(results_csv):
            continue
        
        results_df = pd.read_csv(results_csv)

        # Process each bout
        bouts = []
        for index, row in results_df.iterrows():
            wav_file = row['wav_filename']
            wav_file_path = os.path.join(songs_dir, wav_file)
            try:
                fs, data = wavfile.read(wav_file_path)
            except PermissionError as e:
                print(f"PermissionError: {e}")
                continue
            
            roi_wav_start = int(row['wav_file_start_time'] * fs)
            roi_wav_end = int(row['wav_file_end_time'] * fs)
            
            # Add 1 second padding at start and end of each bout
            start_idx = max(0, roi_wav_start - fs)
            end_idx = min(len(data), roi_wav_end + fs)
            
            bout_signal = data[start_idx:end_idx]
            spectral_entropy = calculate_spectral_entropy(bout_signal, fs)
            
            bouts.append({
                'spectral_entropy': spectral_entropy,
                'total_spectral_entropy': np.sum(spectral_entropy),
                'start_idx': start_idx,
                'end_idx': end_idx,
                'wav_file': wav_file_path
            })

        # Sort bouts based on total summed spectral entropy
        bouts.sort(key=lambda x: x['total_spectral_entropy'], reverse=True)

        # Align all bouts to the common signal at the start of the bout
        aligned_bouts = []
        reference_bout = bouts[0]['spectral_entropy']
        for bout in bouts:
            correlation = np.correlate(reference_bout, bout['spectral_entropy'], mode='full')
            shift = np.argmax(correlation) - len(reference_bout) + 1
            aligned_bout = np.roll(bout['spectral_entropy'], shift)
            aligned_bouts.append(aligned_bout)

        # Make a figure in which each row is a bout, the x-axis is time, and the color is the spectral entropy
        plt.figure(figsize=(10, len(aligned_bouts)))
        for i, aligned_bout in enumerate(aligned_bouts):
            plt.imshow(aligned_bout[np.newaxis, :], aspect='auto', cmap='viridis', extent=[0, len(aligned_bout) / fs, i, i + 1])
        
        plt.xlabel('Time (s)')
        plt.ylabel('Bout')
        plt.yticks(np.arange(len(aligned_bouts)) + 0.5, np.arange(1, len(aligned_bouts) + 1))
        plt.gca().invert_yaxis()
        plt.tight_layout()
        output_svg = os.path.join(hatch_path, 'bouts_spectral_entropy.svg')
        plt.savefig(output_svg, format='svg')
        plt.show()
